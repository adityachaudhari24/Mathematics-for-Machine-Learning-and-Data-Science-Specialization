# %% [markdown]
# #### Adding two vectors in Python using NumPy

# %%
from numpy import array
v = array([3,2])
w = array([2,-1])
# sum the vectors
v_plus_w = v + w
# display summed vector
print(v_plus_w) # [5, 1]
# Out:
# [5 1]

# %% [markdown]
# visual way

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Scaling a number in Python using NumPy
# - important detail to note here is that scaling a vector does not change its
# direction, only its magnitude.
# - scaling by a negative number has not
# really changed direction in that it still exists on the same line. This segues
# us into a key concept called linear dependence.

# %%
from numpy import array
v = array([3,1])
# scale the vector
scaled_v = 2.0 * v
# display scaled vector
print(scaled_v) # [6 2]
# Out:
# [6. 2.]

# %% [markdown]
# ### what is matrix and why is it important
# A matrix is a collection of vectors (such as ˆ i,
# ˆ j), that can have multiple
# rows and columns, and is a convenient way to package data. We can use ˆ i
# and ˆ j to create any vector we want by scaling and adding them.
# #### Example of a matrix
# A simple example of a matrix is:
# ```
# | 1  2 |
# | 3  4 |
# ```
# This matrix has 2 rows and 2 columns, and each element can represent a different value.

# %% [markdown]
# #### Generally with linear transformations, there are four movements you can achieve
# - These four linear transformations are a central part of linear algebra.
# - ![image.png](attachment:image.png)
